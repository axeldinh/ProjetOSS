# %%
import os
import pandas as pd

# %%
path = "/Users/Arthur/Desktop/Projets/ProjetOSS/Datas/Sous-titres/Script_oss2.txt"
oss = []
for line in open(path,'r'):
    if line.startswith('#'):
        temp = line.split("\n")
        oss.append(temp[0])
oss
# Out:
# ["#C'est gentil.",
#  '#Qui sont ces gens ?',
#  '#Ah... Enfin !',
#  '#Ils sont perdus.',
#  '#Tout va bien,Comtesse ?',
#  '#Mais je vous en prie. On a frôlé la catastrophe.',
#  "#Ah Je n'ai fait que mon devoir, Comtesse. Mais à l'avenir,vous devriez vous méfiez de M. Li.Et des Chinoisen général, d'ailleurs.La fortune de la famille impériale attire bien des convoitises.",
#  '#Les sales jaunes.',
#  '#Au temps pour moi.',
#  "#Oh, ma foi... il ne tient qu'à vous de m'en laisser explorer une partie. Si intime soit-elle.",
#  '#Bonjour, Fayolle. ',
#  '#Bonjour, Dutran.',
#  '#Salut, Corbier.',
#  '#Poulard !',
#  '#Bonjour bonjour',
#  '#Très bien,je vous remercie Ledentu Et vous vous allez bien ?',
#  '#Ah! Elle est pas mal, celle-là. Je l\'aime bien. "Comme un lundi".',
#  '#Bonjour Jean-Pierre. Très réussi, méconnaissable.',
#  "#Je t'en prie mon vieux.",
#  '#Bonjour Mayeux, Bonjour Castaing.',
#  '#Toujours pas de nouvelle de Picot?',
#  '#Et Lefranc ?',
# ...

# %%
path2 = "/Users/Arthur/Desktop/Projets/ProjetOSS/Datas/Sous-titres/Script_oss2_parsed.txt"
file2 = open(path2,'w')
for line in oss:
    file2.write(line+'\n')
file2.close()
