# %%
import os
import pandas as pd
import re

# %%
data=list()
for file in os.listdir(directory):
    if file.endswith('.mp3'):
        temp =["2"]+re.split("_|.mp3",file)[1:-1]+["mp3"]
        data.append(temp)
        
data
# Out:
# [['2', 'Scene41', 'Mais non, enfin vous savez bien que non ', 'mp3'],
#  ['2', 'Scene16', 'Bill, que veulent ces marginaux', 'mp3'],
#  ['2',
#   'Scene38',
#   "Bill tu n'est pas bien ? Mais qu'est ce que tu fabriques ?",
#   'mp3'],
#  ['2', 'Scene17', 'Cette ville est absolument maginifique', 'mp3'],
#  ['2',
#   'Scene37',
#   'On se donne rendez-vous au bureau de Bill Tremendous',
#   'mp3'],
#  ['2', 'Scene5', "D'accord faisons comme ça", 'mp3'],
#  ['2', 'Scene5', 'Hubert rigole encore comme un con', 'mp3'],
#  ['2', 'Scene39', 'On se connait non ?', 'mp3'],
#  ['2', 'Scene1', 'On a frolé la catastrophe', 'mp3'],
#  ['2', 'Scene9', 'Bonjour ...', 'mp3'],
#  ['2', 'Scene37', 'Je peux telephoner ?', 'mp3'],
#  ['2', 'Scene30', "C'est parce qu'elle est juive", 'mp3'],
#  ['2', 'Scene8', 'Charmant voyage', 'mp3'],
#  ['2', 'Scene40', "Qu'est ce qu'il fout encore ?", 'mp3'],
#  ['2', 'Scene26', "Bon ecoutez mon petit, j'ai fait mon boulot moi", 'mp3'],
# ...

# %%
df = pd.DataFrame(data=data,columns=["Film","Scene","Reference","Format"])
df.to_csv(os.getcwd()+"ref_list_2.csv")
